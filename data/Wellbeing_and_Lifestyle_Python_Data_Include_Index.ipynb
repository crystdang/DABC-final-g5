# %%
import pandas as pd

# %%
# Read dataset without index into jupyter notebook
Df = pd.read_csv("Wellbeing_and_lifestyle_data_Kaggle.csv")

# %%
Df.head(100)
# Out:
#    Timestamp  FRUITS_VEGGIES DAILY_STRESS  PLACES_VISITED  CORE_CIRCLE  \
# 0     7/7/15               3            2               2            5
# 1     7/7/15               2            3               4            3
# 2     7/7/15               2            3               3            4
# 3     7/7/15               3            3              10            3
# 4     7/7/15               5            1               3            3
# ..       ...             ...          ...             ...          ...
# 95   7/21/15               2            3              10            4
# 96   7/21/15               1            5               0            1
# 97   7/21/15               5            5               2            2
# 98   7/21/15               1            3              10            6
# 99   7/21/15               1            3              10            6
#
#     SUPPORTING_OTHERS  SOCIAL_NETWORK  ACHIEVEMENT  DONATION  BMI_RANGE  ...  \
# ...

# %%
# Export dataset with index
Df.to_csv("Wellbeing_and_lifestyle_data_with_Index.csv", index_label="Survey_ID")
